# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here

import pandas as pd

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here

temp = pd.read_csv("Temp_States.csv")

# %% [markdown]
# #### Print `temp`

# %%
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here

temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here

temp[temp.State == "New York"]
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here

temp[temp.State == "New York"]["Temperature"].mean()
# Out:
# 10.74074074074074

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here

temp[temp.Temperature > 15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here

temp[temp.Temperature > 15]["City"]
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp[(temp.Temperature > 15) & (temp.Temperature < 20)]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here

states = ["New York", "Connecticut", "New Jersey"]

for state in states:
    print(state + " mean", temp[temp.State == state]["Temperature"].mean())
    print(state + " standard deviation", temp[temp.State == state]["Temperature"].std())
# Out:
# New York mean 10.74074074074074
# New York standard deviation 8.133404168888054
# Connecticut mean 15.833333333333332
# Connecticut standard deviation 1.9641855032959645
# New Jersey mean 21.11111111111111
# New Jersey standard deviation 1.5713484026367717

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here

employee = pd.read_csv("employee.csv")

print(employee)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here

employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
print(employee["Years"].plot.hist())
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print(employee["Salary"].plot.hist())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here

employee.Salary.mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here

employee["Salary"].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here

employee["Salary"].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here

employee.sort_values(by = "Salary").head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30
# 0   Jose         IT  Bachelor      M  analyst      1      35

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here

employee.loc[employee['Name'] == "David"]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here

employee.loc[employee['Name'] == "David"]["Salary"]
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here

employee.loc[employee["Title"] == "associate"]
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method

employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method

employee[0:3]

employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here

employee[(employee.Title == "associate") & (employee.Salary > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here

employee.groupby(["Years"]).mean()
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here

employee[["Title", "Salary"]].groupby(["Title"]).mean()
# Out:
#               Salary
# Title
# VP         70.000000
# analyst    32.500000
# associate  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here

employee.boxplot()

# %%
# print first quartile here

employee.quantile([0.25])
# Out:
#       Years  Salary
# 0.25    2.0    35.0

# %%
# print third quartile here
employee.quantile([0.75])
# Out:
#       Years  Salary
# 0.75    7.0    60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
print(employee[["Gender", "Salary", "Title"]].groupby(by = ["Gender", "Title"]).mean())
# Out:
#                   Salary
# Gender Title
# F      VP           70.0
#        analyst      32.5
#        associate    55.0
# M      VP           70.0
#        analyst      32.5
#        associate    57.5

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here

print(employee[["Department", "Years", "Salary"]].groupby("Department").min())
print(employee[["Department", "Years", "Salary"]].groupby("Department").max())
print(employee[["Department", "Years", "Salary"]].groupby("Department").mean())
# Out:
#             Years  Salary
# Department
# HR              2      30
# IT              1      30
# Sales           2      55
#             Years  Salary
# Department
# HR              8      70
# IT              8      70
# Sales           3      55
#                Years  Salary
# Department
# HR          4.666667   45.00
# IT          4.500000   48.75
# Sales       2.500000   55.00

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

max_salary = employee[["Department", "Salary"]].groupby(employee["Department"], as_index = False).max()
min_salary = employee[["Department", "Salary"]].groupby("Department", as_index = False).min()

merged_salaries = pd.merge(max_salary, min_salary, on = "Department")

merged_salaries.rename(columns = {"Salary_x": "Max_salary", "Salary_y": "Min_salary"}, inplace = True)

merged_salaries["Difference"] = merged_salaries["Max_salary"] - merged_salaries["Min_salary"]

print(merged_salaries)
# Out:
#   Department  Max_salary  Min_salary  Difference
# 0         HR          70          30          40
# 1         IT          70          30          40
# 2      Sales          55          55           0

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here

orders = pd.read_csv("Orders.zip")

print(orders)
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here

orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  object
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  object
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  object
#  10  UnitPrice     397924 non-null  float64
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  object
#  13  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB

# %%
# your answer here

orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here

grouped_orders_nonzero = orders[orders["amount_spent"] > 0]

grouped_orders = grouped_orders_nonzero.groupby("InvoiceNo").sum()

print(grouped_orders.head())

grouped_orders["amount_spent"].mean()
# Out:
#            Unnamed: 0   year  month  day  hour  Quantity  UnitPrice  \
# InvoiceNo
# 536365             21  14070     84   21    56        40      27.37
# 536366             15   4020     24    6    16        12       3.70
# 536367            174  24120    144   36    96        83      58.24
# 536368             90   8040     48   12    32        15      19.10
# 536369             25   2010     12    3     8         3       5.95
#
#            CustomerID  amount_spent
# InvoiceNo
# 536365         124950        139.12
# 536366          35700         22.20
# 536367         156564        278.73
# 536368          52188         70.05
# 536369          13047         17.85
# 480.86595639973945

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here

grouped_orders["amount_spent"].max()
# Out:
# 168469.6

# %%
# your answer here

grouped_orders["amount_spent"].min()
# Out:
# 0.38

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here

spain_customers = orders[orders["Country"] == "Spain"]

print(spain_customers)
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# ...            ...        ...       ...   ...    ...  ...   ...
# 394733      535271     581193     23291  2011     12    3    17
# 394734      535272     581193    85232D  2011     12    3    17
# 394735      535273     581193     22721  2011     12    3    17
# 394736      535274     581193     23241  2011     12    3    17
# 394737      535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here

spain_customers["CustomerID"].nunique()
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here

customers = orders.groupby("CustomerID").sum()

fifty = customers[customers["Quantity"] > 50]

print(fifty)
# Out:
#             Unnamed: 0  InvoiceNo     year  month   day   hour  Quantity  \
# CustomerID
# 12346            61619     541431     2011      1     2     10     74215
# 12347         42441700  101296926   365971   1383   441   2219      2458
# 12348          2807120   16869685    62324    257   111    472      2341
# 12349         35444274   42165457   146803    803    73    657       631
# 12350          1365627    9231629    34187     34    51    272       197
# ...                ...        ...      ...    ...   ...    ...       ...
# 18278          3262446    5116428    18099     81    18     99        66
# 18281          1560699    3895248    14077     42    49     70        54
# 18282          4642134    6838540    24132    116    60    146       103
# 18283        233950830  425704048  1520316   5503  2489  10346      1397
# 18287         21958901   39474556   140770    555   332    697      1586
#
#             UnitPrice  amount_spent
# CustomerID
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here

spain_customers_grouped = spain_customers.groupby("CustomerID").sum()

fifty_spain = spain_customers_grouped[spain_customers_grouped["Quantity"] > 50]

print(fifty_spain)
# Out:
#             Unnamed: 0  InvoiceNo    year  month   day  hour  Quantity  \
# CustomerID
# 12354          9645139   31952838  116638    232   232   754       530
# 12417          3938336   12682154   46253     92    92   299       267
# 12421         11812978   25167687   90495    282   178   538       484
# 12442          6377106    6971460   24132    144    24   168       182
# 12445          1915882    2308500    8044     44    16    72        62
# 12448          9246897   12603492   44242    220    66   286       243
# 12450          1898462    4462114   16088     50    48   112       128
# 12454          5979495    8568825   30165    150    75   255      1006
# 12455         13890841   26985556   96528    366   156   626       566
# 12462         14130247   34448972  124682    322   142   758       536
# 12484         85792569  193177283  695806   2152  1907  4594      2191
# 12502         30624610   81550414  295617    829   455  1541       820
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here

orders[orders["amount_spent"] == 0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here

orders[orders["Description"].str.contains("lunch bag", case = False)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here

orders[(orders["Description"].str.contains("lunch bag", case = False)) & (orders["year"] == 2011)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here

spain_customers_grouped.hist("amount_spent")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DA470B2088>]],
#       dtype=object)

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here

august = orders[orders["month"] == 8]

print(august)
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here

orders_month = orders[orders["month"] == 8].groupby("Country").nunique()

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here

min_spending = orders[orders["amount_spent"] > 0]

countries = min_spending["Country"].unique().tolist()

average_spendings = {}

for country in countries:
    avg_spending = min_spending[min_spending["Country"] == country].groupby("CustomerID").mean()
    country_spending = avg_spending["amount_spent"].mean()
    average_spendings[f"{country}"] = country_spending
    
average_spendings
# Out:
# {'United Kingdom': 71.75831958893198,
#  'France': 23.075503987119124,
#  'Australia': 46.94358667124922,
#  'Netherlands': 40.39563401542626,
#  'Germany': 28.51914727901285,
#  'Norway': 34.467287632521604,
#  'EIRE': 45.38341767723753,
#  'Switzerland': 31.8416559243908,
#  'Spain': 39.4415902500799,
#  'Poland': 27.56383225708537,
#  'Portugal': 22.539308612008284,
#  'Italy': 21.902509993025415,
#  'Belgium': 20.514043994819968,
#  'Lithuania': 47.45885714285714,
#  'Japan': 270.63558860083793,
#  'Iceland': 23.681318681318682,
#  'Channel Islands': 80.45502138476435,
#  'Denmark': 66.87640064220018,
#  'Cyprus': 43.80486264031536,
#  'Sweden': 40.24745894674432,
#  'Finland': 36.85094405813148,
#  'Austria': 36.54820483507442,
#  'Greece': 34.60755744949495,
#  'Singapore': 95.85265765765766,
#  'Lebanon': 37.64177777777778,
#  'United Arab Emirates': 28.150140350877194,
#  'Israel': 27.98445973765543,
#  'Saudi Arabia': 16.213333333333335,
#  'Czech Republic': 33.0696,
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here

orders[["Description", "UnitPrice"]].sort_values("UnitPrice", ascending = False).iloc[0]
# Out:
# Description    postage
# UnitPrice      8142.75
# Name: 118352, dtype: object

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here


grouped_2010 = orders[orders["year"] == 2010].groupby(["InvoiceNo", "year"]).sum()
average_spnt_2010 = grouped_2010["amount_spent"].mean()

grouped_2011 = orders[orders["year"] == 2011].groupby(["InvoiceNo", "year"]).sum()
average_spnt_2011 = grouped_2011["amount_spent"].mean()

print("Average amount spent in 2010 is: " + str(average_spnt_2010))
print("Average amount spent in 2011 is: " + str(average_spnt_2011))
# Out:
# Average amount spent in 2010 is: 409.08134999999993
# Average amount spent in 2011 is: 486.61846486928135
