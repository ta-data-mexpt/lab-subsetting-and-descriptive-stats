# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
#Lee el archivo csv 
temp = pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# Revisa los tipos de columnas
temp.dtypes
#sólo tiene un campo númerico que es Temperature
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
#Usa un filtro en la columna State donde sea New York y guarda la salida en un nuevo DF
temp_NY = temp[temp['State']=='New York']

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
#Como sólo tiene una columna númerica, utilizo mean() sobre todo el DF.
temp_NY.mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
#Hace un filtro en la columna Temperature y guarda en un nuevo DF sólo las ciudades y estados correspondientes
temp_M15 = temp[temp['Temperature']>15][['City','State']]
temp_M15
# Out:
#        City        State
# 0       NYC     New York
# 3  Hartford  Connecticut
# 5    Treton   New Jersey
# 6    Newark   New Jersey

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
#Hace un filtro en la columna Temperature y guarda en un nuevo DF sólo las ciudades correspondientes
temp_M15_city = temp[temp['Temperature']>15]['City']
temp_M15_city
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
#Hace los filtros en la columna Temperature y guarda en un nuevo DF sólo las ciudades correspondientes
temp_M15_m20 = temp[(temp['Temperature']>15) & (temp['Temperature']<20)]['City']
temp_M15_m20
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
#Del DF original, agrupa por la columna State para obtener el promedio y la desviación estandar de las agregaciones
temp.groupby(['State']).agg(['mean','std'])
# Out:
#             Temperature
#                    mean       std
# State
# Connecticut   15.833333  1.964186
# New Jersey    21.111111  1.571348
# New York      10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# Carga el archivo en un DF llamado Employee y lo imprimo para ver la info
employee = pd.read_csv('employee.csv')
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
#El DF tiene 5 columnas categoricas y 2 númericas de tipo entero
employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# utilizamos hist para generar el histograma
employee.hist()
# Con los datos completos se puede observar que hay sesgos tanto para la izquierda como para la derecha
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015F7905C880>,
# ...
#       dtype=object)

# %% [markdown]
# #### What's the average salary in this company?

# %%
# Uso mean() sobre la columna Salary para obtener el promedio
employee['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# Uso max() sobre la columna Salary para obtener el salario máximo
employee['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# Uso min() sobre la columna Salary para obtener el salario mínimo y lo guardo en una variable
min_salary = employee['Salary'].min()
min_salary
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# Filtro donde salario sea igual al valor de mi variable con el mínimo y sólo que me imprima el nombre
min_salary_employees =  employee[employee['Salary']==min_salary]['Name']
min_salary_employees
# Out:
# 1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# Filtro por nombre para obtener a David
employee[employee['Name']=='David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# al filtro anterior le agregosólo la´columna que quiero
employee[employee['Name']=='David']['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# Filtro por title para obtener a associate
employee[employee['Title']=='associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# 1 method: loc
employee.loc[0:2]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# 2nd method: iloc
employee.iloc[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# Filtro con las condiciones solicitadas
associates = employee[(employee['Title']=='associate') & (employee['Salary']>55)]
associates
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# Agrupo por Years y pido la media de salario para cada grupo
employee.groupby('Years').agg({'Salary':'mean'})
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# Agrupo por title y calculo la media de salario para cada grupo
employee.groupby('Title').agg({'Salary':'mean'})
# Out:
#               Salary
# Title
# VP         70.000000
# analyst    32.500000
# associate  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
employee.boxplot()

# %%
# print first quartile here
Q1_Years = employee['Years'].quantile(0.25)
print(Q1_Years)
Q1_Salary = employee['Salary'].quantile(0.25)
print(Q1_Salary)
# Out:
# 2.0
# 35.0

# %%
# print third quartile here
Q3_Years = employee['Years'].quantile(0.75)
print(Q3_Years)
Q3_Salary = employee['Salary'].quantile(0.75)
print(Q3_Salary)
# Out:
# 7.0
# 60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# agrupo por género y calculo el promedio de cada uno
employee.groupby('Gender').agg({'Salary':'mean'})
#Sí, son diferentes los salarios dependiendo del género
# Out:
#         Salary
# Gender
# F         47.5
# M         50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
#Agrupo por departamento y pido el mínimo, media y máximo sin especificar las columnas para que me traiga para todas las númericas
employee.groupby('Department').agg(['min','mean','max'])
# Out:
#            Years               Salary
#              min      mean max    min   mean max
# Department
# HR             2  4.666667   8     30  45.00  70
# IT             1  4.500000   8     30  48.75  70
# Sales          2  2.500000   3     55  55.00  55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
#Opción 1: Agrupando por departamento, utilizando la función ptp de numpy y tomando sólo la columna Salary
opcion1 = employee.groupby('Department').agg(np.ptp)['Salary']
#Opción 2: Agrupando por departament, agregando una lambda con la diferencia del méximo y el mpinimo
opcion2 = employee.groupby(['Department']
                ).agg({'Salary':lambda x: x.max() - x.min()})
print(opcion1)
opcion2
# Out:
# Department
# HR       40
# IT       40
# Sales     0
# Name: Salary, dtype: int64
#             Salary
# Department
# HR              40
# IT              40
# Sales            0

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv('Orders.zip',compression='zip',index_col=0)
orders
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 0          536365    85123A  2010     12    3     8
# 1          536365     71053  2010     12    3     8
# 2          536365    84406B  2010     12    3     8
# 3          536365    84029G  2010     12    3     8
# 4          536365    84029E  2010     12    3     8
# ...           ...       ...   ...    ...  ...   ...
# 541904     581587     22613  2011     12    5    12
# 541905     581587     22899  2011     12    5    12
# 541906     581587     23254  2011     12    5    12
# 541907     581587     23255  2011     12    5    12
# 541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                       white metal lantern         6  2010-12-01 08:26:00
# 2            cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.dtypes
# Out:
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
# your answer here
orders.describe()
# Out:
#            InvoiceNo           year          month            day  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   560617.126645    2010.934259       7.612537       3.614555
# std     13106.167695       0.247829       3.416527       1.928274
# min    536365.000000    2010.000000       1.000000       1.000000
# 25%    549234.000000    2011.000000       5.000000       2.000000
# 50%    561893.000000    2011.000000       8.000000       3.000000
# 75%    572090.000000    2011.000000      11.000000       5.000000
# max    581587.000000    2011.000000      12.000000       7.000000
#
#                 hour       Quantity      UnitPrice     CustomerID  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean       12.728247      13.021823       3.116174   15294.315171
# std         2.273535     180.420210      22.096788    1713.169877
# min         6.000000       1.000000       0.000000   12346.000000
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
#Suponiendo que se refiere a UnitPrice, calculo la media de esa columna
orders['UnitPrice'].mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# Obtengo el mínimo del UnitPrice
orders['UnitPrice'].min()
# Out:
# 0.0

# %%
# Obtengo el máximo del UnitPrice
orders['UnitPrice'].max()
# Out:
# 8142.75

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
orders_Spain = orders[orders['Country']=='Spain']
orders_Spain.head()
# Out:
#       InvoiceNo StockCode  year  month  day  hour              Description  \
# 6421     536944     22383  2010     12    5    12  lunch bag suki  design
# 6422     536944     22384  2010     12    5    12  lunch bag pink polkadot
# 6423     536944     20727  2010     12    5    12  lunch bag  black skull.
# 6424     536944     20725  2010     12    5    12  lunch bag red retrospot
# 6425     536944     20728  2010     12    5    12      lunch bag cars blue
#
#       Quantity          InvoiceDate  UnitPrice  CustomerID Country  \
# 6421        70  2010-12-03 12:20:00       1.65       12557   Spain
# 6422       100  2010-12-03 12:20:00       1.45       12557   Spain
# 6423        60  2010-12-03 12:20:00       1.65       12557   Spain
# 6424        70  2010-12-03 12:20:00       1.65       12557   Spain
# 6425       100  2010-12-03 12:20:00       1.45       12557   Spain
#
#       amount_spent
# 6421         115.5
# 6422         145.0
# 6423          99.0
# 6424         115.5
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
orders_Spain['Country'].value_counts()
# Out:
# Spain    2485
# Name: Country, dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
orders[orders['Quantity']>50]['CustomerID']
# Out:
# 46        13748
# 83        15291
# 96        14688
# 102       14688
# 176       16029
#           ...
# 541702    18102
# 541703    16626
# 541711    16626
# 541746    15311
# 541867    13777
# Name: CustomerID, Length: 11609, dtype: int64

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
orders_Spain_M50 = orders[(orders['Country']=='Spain') & (orders['Quantity']>50)]
orders_Spain_M50.head()
# Out:
#       InvoiceNo StockCode  year  month  day  hour              Description  \
# 6421     536944     22383  2010     12    5    12  lunch bag suki  design
# 6422     536944     22384  2010     12    5    12  lunch bag pink polkadot
# 6423     536944     20727  2010     12    5    12  lunch bag  black skull.
# 6424     536944     20725  2010     12    5    12  lunch bag red retrospot
# 6425     536944     20728  2010     12    5    12      lunch bag cars blue
#
#       Quantity          InvoiceDate  UnitPrice  CustomerID Country  \
# 6421        70  2010-12-03 12:20:00       1.65       12557   Spain
# 6422       100  2010-12-03 12:20:00       1.45       12557   Spain
# 6423        60  2010-12-03 12:20:00       1.65       12557   Spain
# 6424        70  2010-12-03 12:20:00       1.65       12557   Spain
# 6425       100  2010-12-03 12:20:00       1.45       12557   Spain
#
#       amount_spent
# 6421         115.5
# 6422         145.0
# 6423          99.0
# 6424         115.5
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
orders[orders['UnitPrice']==0]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 9302       537197     22841  2010     12    7    14
# 33576      539263     22580  2010     12    4    14
# 40089      539722     22423  2010     12    2    13
# 47068      540372     22090  2011      1    4    16
# 47070      540372     22553  2011      1    4    16
# 56674      541109     22168  2011      1    4    15
# 86789      543599    84535B  2011      2    4    13
# 130188     547417     22062  2011      3    3    10
# 139453     548318     22055  2011      3    3    12
# 145208     548871     22162  2011      4    1    14
# 157042     550188     22636  2011      4    4    18
# 187613     553000     47566  2011      5    4    15
# 198383     554037     22619  2011      5    5    14
# 279324     561284     22167  2011      7    2    12
# 282912     561669     22960  2011      7    4    17
# 285657     561916         M  2011      8    1    11
# 298054     562973     23157  2011      8    4    11
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
orders[orders['Description'].str.contains('lunch bag')]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 93         536378     20725  2010     12    3     9
# 174        536385     22662  2010     12    3     9
# 363        536401     22662  2010     12    3    11
# 368        536401     20725  2010     12    3    11
# 369        536401     22382  2010     12    3    11
# ...           ...       ...   ...    ...  ...   ...
# 540436     581486     23207  2011     12    5     9
# 541695     581538     20727  2011     12    5    11
# 541696     581538     20725  2011     12    5    11
# 541862     581581     23681  2011     12    5    12
# 541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# 174     lunch bag dolly girl design        10  2010-12-01 09:56:00       1.65
# 363     lunch bag dolly girl design         1  2010-12-01 11:21:00       1.65
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
orders[(orders['year']==2011)&(orders['Description'].str.contains('lunch bag'))]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 42678      540015     20725  2011      1    2    11
# 42679      540015     20726  2011      1    2    11
# 42851      540023     22382  2011      1    2    12
# 42852      540023     20726  2011      1    2    12
# 43616      540098     22384  2011      1    2    15
# ...           ...       ...   ...    ...  ...   ...
# 540436     581486     23207  2011     12    5     9
# 541695     581538     20727  2011     12    5    11
# 541696     581538     20725  2011     12    5    11
# 541862     581581     23681  2011     12    5    12
# 541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 42678       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# 42679            lunch bag woodland        10  2011-01-04 11:40:00       1.65
# 42851    lunch bag spaceboy design          2  2011-01-04 12:58:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
orders_Spain['amount_spent'].hist()

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders[orders['month']==8]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 285421     561904     22075  2011      8    1     8
# 285422     561904    85049E  2011      8    1     8
# 285423     561905     21385  2011      8    1     9
# 285424     561905    84970L  2011      8    1     9
# 285425     561905    84970S  2011      8    1     9
# ...           ...       ...   ...    ...  ...   ...
# 320688     565067     22644  2011      8    3    17
# 320689     565067     22645  2011      8    3    17
# 320690     565067     22637  2011      8    3    17
# 320691     565067     22646  2011      8    3    17
# 320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 285421         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# 285422            scandinavian reds ribbons       156  2011-08-01 08:30:00
# 285423      ivory hanging decoration  heart        24  2011-08-01 09:31:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
orders[orders['month']==8]['month'].value_counts()
# Out:
# 8    27013
# Name: month, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
orders.groupby('Country').agg({'amount_spent':'mean'})
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
max_item = orders['UnitPrice'].max()
orders[orders['UnitPrice']==max_item]['Description']
# Out:
# 173382    postage
# Name: Description, dtype: object

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
orders.groupby('year').agg({'amount_spent':'mean'})
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
