# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
import numpy as np
import pandas as pd
import matplotlib
# %matplotlib inline

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
temp = pd.read_csv('/Users/user/lab-subsetting-and-descriptive-stats/your-code/Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
temp.dtypes
#tenemos dos columnas que incluyen string, por eso aparcen como objeto 
#y uno que es de temperatura y por eso aparece como float
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
temp[temp.State == 'New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
NY = temp[temp.State == 'New York']
NY['Temperature'].mean()
# Out:
# 10.74074074074074

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
temp[temp.Temperature > 15][['City', 'State']]
#Cuando solicitamos más de una columna para visualizar estos se ponen en doble corchete
# Out:
#        City        State
# 0       NYC     New York
# 3  Hartford  Connecticut
# 5    Treton   New Jersey
# 6    Newark   New Jersey

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
temp[temp.Temperature > 15][['City']]
#temp[temp.Temperature > 15]['City']
#si solo dejamos la columna solicitada en un solo corchete lo visualiza como serie
# Out:
#        City
# 0       NYC
# 3  Hartford
# 5    Treton
# 6    Newark

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
temp[(temp.Temperature > 15)&(temp.Temperature < 20)][['City']]
#primero escribí la condicion y posterior escogí la columna necesaria, la condicion debe de ir entre parentesis además
#de los corchetes
# Out:
#        City
# 0       NYC
# 3  Hartford

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
temp.groupby('State').agg({'Temperature':['mean','std']})
# Out:
#             Temperature
#                    mean       std
# State
# Connecticut   15.833333  1.964186
# New Jersey    21.111111  1.571348
# New York      10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
employee = pd.read_csv('/Users/user/lab-subsetting-and-descriptive-stats/your-code/Employee.csv')

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
employee.dtypes
#las columnas que describen alguna característica estan en formato objeto 
#año lo está reconociendo como un entero, revisando la data es una cuenta de los años que el trabajador ha colaborado ahi
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %%
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
employee.hist(bins=20)
#los histográmas muestran la frecuencia de datos númericos y reporta la frecuencia
#Years: la mayoría de los empleados tienen de 1 a 3 años y una minoría rebasa los 7 años
#Salary: en su mayoría, los empleados con mayor antigüedad son los que tienen salarios más altos
# Out:
# array([[<AxesSubplot:title={'center':'Years'}>,
#         <AxesSubplot:title={'center':'Salary'}>]], dtype=object)

# %% [markdown]
# #### What's the average salary in this company?

# %%
employee['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
employee['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
employee['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
employee['Name'][employee['Salary'] == employee['Salary'].min()]
# Out:
# 1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
employee.query('Name=="David"')
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
employee.query('Name=="David"')['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
employee.query('Title =="associate"')
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
employee[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
employee.iloc[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
employee[(employee.Title=='associate')&(employee.Salary> 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
employee.groupby('Years')[['Salary']].mean()
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
employee.groupby('Title')[['Salary']].mean()
# Out:
#               Salary
# Title
# VP         70.000000
# analyst    32.500000
# associate  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
employee.boxplot()
# Out:
# <AxesSubplot:>

# %%
employee.quantile(0.25)
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
employee.quantile(0.75)
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
employee.groupby('Gender')[['Salary']].mean()
#es diferente
# Out:
#         Salary
# Gender
# F         47.5
# M         50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
employee.groupby('Department').agg(['min','mean','max'])
# Out:
#            Years               Salary
#              min      mean max    min   mean max
# Department
# HR             2  4.666667   8     30  45.00  70
# IT             1  4.500000   8     30  48.75  70
# Sales          2  2.500000   3     55  55.00  55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
employee.groupby('Department')

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
orders = pd.read_csv('/Users/user/lab-subsetting-and-descriptive-stats/your-code/Orders.csv')
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
orders['amount_spent'].mean()
# Out:
# 22.394748504739596

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
orders['amount_spent'].max()
# Out:
# 168469.6

# %%
orders['amount_spent'].min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
orders.query('Country =="Spain"')['CustomerID'].unique().tolist()
# Out:
# [12557,
#  17097,
#  12540,
#  12551,
#  12484,
#  12539,
#  12510,
#  12421,
#  12502,
#  12462,
#  12507,
#  12541,
#  12547,
#  12597,
#  12545,
#  12596,
#  12354,
#  12417,
#  12455,
#  12450,
#  12548,
#  12556,
#  12550,
#  12546,
#  12454,
#  12448,
#  12544,
#  12538,
#  12445,
#  12442]

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
orders.query('Country =="Spain"')['CustomerID'].value_counts()
# Out:
# 12540    478
# 12484    346
# 12539    273
# 17097    211
# 12597    206
# 12502    147
# 12556    121
# 12546     69
# 12462     62
# 12354     58
# 12550     57
# 12541     52
# 12545     50
# 12455     48
# 12421     45
# 12510     33
# 12557     33
# 12596     27
# 12417     23
# 12507     22
# 12448     22
# 12538     21
# 12544     19
# 12454     15
# 12442     12
# 12551     10
# 12547      8
# 12450      8
# 12548      5
# 12445      4
# Name: CustomerID, dtype: int64

# %%
print(len(orders.query('Country =="Spain"')['CustomerID']))
# Out:
# 2485

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
empleados = orders.groupby('CustomerID')['Quantity'].sum().reset_index()
empleados[(empleados.Quantity > 50)]
# Out:
#       CustomerID  Quantity
# 0          12346     74215
# 1          12347      2458
# 2          12348      2341
# 3          12349       631
# 4          12350       197
# ...          ...       ...
# 4333       18278        66
# 4335       18281        54
# 4336       18282       103
# 4337       18283      1397
# 4338       18287      1586
#
# [4091 rows x 2 columns]

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
orders[(orders.Country=='Spain')&(orders.Quantity> 50)][['CustomerID','Quantity']].sort_values('Quantity').reset_index(drop=True)
# Out:
#     CustomerID  Quantity
# 0        12557        60
# 1        12484        60
# 2        12557        70
# 3        12557        70
# 4        12557        72
# 5        12597        72
# 6        12597        72
# 7        12597        72
# 8        12454        72
# 9        12454        72
# 10       12557        72
# 11       12557        72
# 12       12596        96
# 13       12546        96
# 14       12557       100
# 15       12557       100
# 16       12557       100
# 17       12557       100
# 18       12557       100
# 19       12557       100
# 20       12507       128
# 21       12507       128
# 22       12507       128
# 23       12507       128
# 24       12557       144
# 25       12507       144
# 26       12557       144
# 27       12557       150
# 28       12557       150
# 29       12557       150
# 30       12454       200
# 31       12557       200
# 32       12454       288
# 33       12557       288
# 34       12557       360
# 35       12557       360
# ...

# %% [markdown]
# #### Select all free orders

# %%
orders.query('amount_spent =="0.0"').reset_index(drop=True)
# Out:
#     Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0         9302     537197     22841  2010     12    7    14
# 1        33576     539263     22580  2010     12    4    14
# 2        40089     539722     22423  2010     12    2    13
# 3        47068     540372     22090  2011      1    4    16
# 4        47070     540372     22553  2011      1    4    16
# 5        56674     541109     22168  2011      1    4    15
# 6        86789     543599    84535B  2011      2    4    13
# 7       130188     547417     22062  2011      3    3    10
# 8       139453     548318     22055  2011      3    3    12
# 9       145208     548871     22162  2011      4    1    14
# 10      157042     550188     22636  2011      4    4    18
# 11      187613     553000     47566  2011      5    4    15
# 12      198383     554037     22619  2011      5    5    14
# 13      279324     561284     22167  2011      7    2    12
# 14      282912     561669     22960  2011      7    4    17
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
orders[orders['Description'].str.contains('lunch bag')].reset_index(drop=True)
# Out:
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0              93     536378     20725  2010     12    3     9
# 1             174     536385     22662  2010     12    3     9
# 2             363     536401     22662  2010     12    3    11
# 3             368     536401     20725  2010     12    3    11
# 4             369     536401     22382  2010     12    3    11
# ...           ...        ...       ...   ...    ...  ...   ...
# 11551      540436     581486     23207  2011     12    5     9
# 11552      541695     581538     20727  2011     12    5    11
# 11553      541696     581538     20725  2011     12    5    11
# 11554      541862     581581     23681  2011     12    5    12
# 11555      541865     581583     20725  2011     12    5    12
#
#                        Description  Quantity          InvoiceDate  UnitPrice  \
# 0          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
orders[(orders.year ==2011)&(orders['Description'].str.contains('lunch bag'))]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
frecuencia = orders.query('Country =="Spain"')[['amount_spent']].reset_index(drop=True)
frecuencia.hist(bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'amount_spent'}>]], dtype=object)

# %% [markdown]
# #### Select all orders made in the month of August

# %%
orders[orders.month == 8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
orders[orders.month == 8]['Country'].value_counts()
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
orders.groupby('Country')['amount_spent'].mean()
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
orders['UnitPrice'].max()
# Out:
# 8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
orders.groupby('year')['amount_spent'].mean()
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
