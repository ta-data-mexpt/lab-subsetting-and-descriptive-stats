# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp.head(10)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
temp.info()
temp.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      object
#  1   State        7 non-null      object
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 296.0+ bytes
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
temp[temp.State == 'New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
temp.groupby('State').mean().loc[['New York']]
# Out:
#           Temperature
# State
# New York    10.740741

# %%
temp.groupby('State').agg('mean').loc[['New York']]
# Out:
#           Temperature
# State
# New York    10.740741

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp[temp.Temperature > 15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp[temp.Temperature > 15][['City']]
# Out:
#        City
# 0       NYC
# 3  Hartford
# 5    Treton
# 6    Newark

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp[((temp.Temperature > 15) & (temp.Temperature < 20))]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %%
temp[((temp.Temperature > 15) & (temp.Temperature < 20))][['City']]
# Out:
#        City
# 0       NYC
# 3  Hartford

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
temp.groupby('State').agg(['mean','std'])
# Out:
# C:\Users\sistemas\AppData\Local\Temp\ipykernel_11276\3026238463.py:2: FutureWarning: ['City'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   temp.groupby('State').agg(['mean','std'])
#             Temperature
#                    mean       std
# State
# Connecticut   15.833333  1.964186
# New Jersey    21.111111  1.571348
# New York      10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee = pd.read_csv('Employee.csv')

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.info()
employee.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9 non-null      object
#  1   Department  9 non-null      object
#  2   Education   9 non-null      object
#  3   Gender      9 non-null      object
#  4   Title       9 non-null      object
#  5   Years       9 non-null      int64
#  6   Salary      9 non-null      int64
# dtypes: int64(2), object(5)
# memory usage: 632.0+ bytes
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
employee.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Years'}>,
#         <AxesSubplot:title={'center':'Salary'}>]], dtype=object)

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here


employee.boxplot('Salary')

print('promedio de salario',employee.Salary.mean(),'\n')
print('el salario que esta en la media',employee.Salary.median(),'\n')

employee.hist('Salary')
# Out:
# promedio de salario 48.888888888888886
#
# el salario que esta en la media 55.0
# array([[<AxesSubplot:title={'center':'Salary'}>]], dtype=object)

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee.boxplot('Salary')
print('el salario mas alto es',employee.Salary.max())

employee.hist('Salary')
# Out:
# el salario mas alto es 70
# array([[<AxesSubplot:title={'center':'Salary'}>]], dtype=object)

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee.boxplot('Salary')
print('el salario mas bajo es',employee.Salary.min())

employee.hist('Salary')
# Out:
# el salario mas bajo es 30
# array([[<AxesSubplot:title={'center':'Salary'}>]], dtype=object)

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here

employee[employee.Salary == 30][['Name']]
# Out:
#     Name
# 1  Maria
# 2  David

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[employee.Name == 'David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee[employee.Name == 'David'][['Salary']]
# Out:
#    Salary
# 2      30

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee[employee.Title == 'associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee.loc[:2]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[(employee.Title == 'associate')&(employee.Salary > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
employee.groupby('Years').agg('mean')
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %%
employee.sort_values('Years')
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 4  Samuel      Sales    Master      M  associate      3      55
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 7   Pedro         IT       Phd      M  associate      7      60
# 6  Carlos         IT    Master      M         VP      8      70
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
employee.groupby('Title').agg('mean')[['Salary']]
# Out:
#               Salary
# Title
# VP         70.000000
# analyst    32.500000
# associate  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
employee.boxplot('Years')
#employee.boxplot('Salary')
# Out:
# <AxesSubplot:>

# %%
print('boxplot de salario es:')
employee.boxplot('Salary')
# Out:
# boxplot de salario es:
# <AxesSubplot:>

# %%
# print first quartile here
print('el primer cuartile de 25% en salario es de ',employee.Salary.quantile(.25))
# Out:
# el primer cuartile de 25% en salario es de  35.0

# %%
# print third quartile here
print('el primer cuartile de 75% en salario es de ',employee.Salary.quantile(.75))
# Out:
# el primer cuartile de 75% en salario es de  60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
employee.groupby('Gender').mean()
# Out:
#         Years  Salary
# Gender
# F         4.0    47.5
# M         4.2    50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
employee.groupby('Department').agg(['min','mean','max'])
# Out:
# C:\Users\sistemas\AppData\Local\Temp\ipykernel_11276\3302724837.py:2: FutureWarning: ['Name', 'Education', 'Gender', 'Title'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   employee.groupby('Department').agg(['min','mean','max'])
#            Years               Salary
#              min      mean max    min   mean max
# Department
# HR             2  4.666667   8     30  45.00  70
# IT             1  4.500000   8     30  48.75  70
# Sales          2  2.500000   3     55  55.00  55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here
employee.groupby('Department').agg([lambda x: np.max(x) - np.min(x)])
#df_nulos.groupby('make', as_index = False)[['cylinders']].agg(['min', 'max', 'mean', lambda x: np.sum(x)/45, np.sum])
# Out:
# C:\Users\sistemas\AppData\Local\Temp\ipykernel_11276\1325873522.py:2: FutureWarning: ['Name', 'Education', 'Gender', 'Title'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   employee.groupby('Department').agg([lambda x: np.max(x) - np.min(x)])
#               Years   Salary
#            <lambda> <lambda>
# Department
# HR                6       40
# IT                7       40
# Sales             1        0

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv('Orders.csv')

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.info()
orders.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  object
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  object
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  object
#  10  UnitPrice     397924 non-null  float64
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  object
#  13  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# 25%         2.000000      11.000000       2.000000       1.250000
# 50%         3.000000      13.000000       6.000000       1.950000
# 75%         5.000000      14.000000      12.000000       3.750000
# max         7.000000      20.000000   80995.000000    8142.750000
#
#           CustomerID   amount_spent
# count  397924.000000  397924.000000
# mean    15294.315171      22.394749
# std      1713.169877     309.055588
# min     12346.000000       0.000000
# 25%     13969.000000       4.680000
# 50%     15159.000000      11.800000
# 75%     16795.000000      19.800000
# max     18287.000000  168469.600000

# %%
orders.head(2)
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
#
#                           Description  Quantity          InvoiceDate  \
# 0  white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                 white metal lantern         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34

# %%
#orders.set_index('InvoiceNo', inplace = True)
orders.set_index('Unnamed: 0', inplace = True)
orders.head(1)
# Out:
#             InvoiceNo StockCode  year  month  day  hour  \
# Unnamed: 0
# 0              536365    85123A  2010     12    3     8
#
#                                    Description  Quantity          InvoiceDate  \
# Unnamed: 0
# 0           white hanging heart t-light holder         6  2010-12-01 08:26:00
#
#             UnitPrice  CustomerID         Country  amount_spent
# Unnamed: 0
# 0                2.55       17850  United Kingdom          15.3

# %%
#orders.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
#orders.head(5)
# Out:
#           StockCode  year  month  day  hour  \
# InvoiceNo
# 536365       85123A  2010     12    3     8
# 536365        71053  2010     12    3     8
# 536365       84406B  2010     12    3     8
# 536365       84029G  2010     12    3     8
# 536365       84029E  2010     12    3     8
#
#                                    Description  Quantity          InvoiceDate  \
# InvoiceNo
# 536365      white hanging heart t-light holder         6  2010-12-01 08:26:00
# 536365                     white metal lantern         6  2010-12-01 08:26:00
# 536365          cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 536365     knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 536365          red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#            UnitPrice  CustomerID         Country  amount_spent
# InvoiceNo
# 536365          2.55       17850  United Kingdom         15.30
# 536365          3.39       17850  United Kingdom         20.34
# 536365          2.75       17850  United Kingdom         22.00
# 536365          3.39       17850  United Kingdom         20.34
# 536365          3.39       17850  United Kingdom         20.34

# %%
# your answer here
orders.describe()
# Out:
#            InvoiceNo           year          month            day  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   560617.126645    2010.934259       7.612537       3.614555
# std     13106.167695       0.247829       3.416527       1.928274
# min    536365.000000    2010.000000       1.000000       1.000000
# 25%    549234.000000    2011.000000       5.000000       2.000000
# 50%    561893.000000    2011.000000       8.000000       3.000000
# 75%    572090.000000    2011.000000      11.000000       5.000000
# max    581587.000000    2011.000000      12.000000       7.000000
#
#                 hour       Quantity      UnitPrice     CustomerID  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean       12.728247      13.021823       3.116174   15294.315171
# std         2.273535     180.420210      22.096788    1713.169877
# min         6.000000       1.000000       0.000000   12346.000000
# 25%        11.000000       2.000000       1.250000   13969.000000
# 50%        13.000000       6.000000       1.950000   15159.000000
# 75%        14.000000      12.000000       3.750000   16795.000000
# max        20.000000   80995.000000    8142.750000   18287.000000
#
#         amount_spent
# count  397924.000000
# mean       22.394749
# std       309.055588
# min         0.000000
# 25%         4.680000
# 50%        11.800000
# 75%        19.800000
# max    168469.600000

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
orders.UnitPrice.mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders.UnitPrice.max()
# Out:
# 8142.75

# %%
# your answer here
orders.UnitPrice.min()
# Out:
# 0.0

# %%
orders.shape
# Out:
# (397924, 12)

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
orders[orders.Country=='Spain']
# Out:
#             InvoiceNo StockCode  year  month  day  hour  \
# Unnamed: 0
# 6421           536944     22383  2010     12    5    12
# 6422           536944     22384  2010     12    5    12
# 6423           536944     20727  2010     12    5    12
# 6424           536944     20725  2010     12    5    12
# 6425           536944     20728  2010     12    5    12
# ...               ...       ...   ...    ...  ...   ...
# 535271         581193     23291  2011     12    3    17
# 535272         581193    85232D  2011     12    3    17
# 535273         581193     22721  2011     12    3    17
# 535274         581193     23241  2011     12    3    17
# 535275         581193     23247  2011     12    3    17
#
#                               Description  Quantity          InvoiceDate  \
# Unnamed: 0
# 6421              lunch bag suki  design         70  2010-12-03 12:20:00
# 6422              lunch bag pink polkadot       100  2010-12-03 12:20:00
# 6423              lunch bag  black skull.        60  2010-12-03 12:20:00
# 6424              lunch bag red retrospot        70  2010-12-03 12:20:00
# 6425                  lunch bag cars blue       100  2010-12-03 12:20:00
# ...                                   ...       ...                  ...
# 535271           dolly girl childrens cup         2  2011-12-07 17:05:00
# 535272      set/3 decoupage stacking tins         1  2011-12-07 17:05:00
# 535273      set of 3 cake tins sketchbook         2  2011-12-07 17:05:00
# 535274       treasure tin gymkhana design         1  2011-12-07 17:05:00
# 535275         biscuit tin 50's christmas         1  2011-12-07 17:05:00
#
#             UnitPrice  CustomerID Country  amount_spent
# Unnamed: 0
# 6421             1.65       12557   Spain        115.50
# 6422             1.45       12557   Spain        145.00
# 6423             1.65       12557   Spain         99.00
# 6424             1.65       12557   Spain        115.50
# 6425             1.45       12557   Spain        145.00
# ...               ...         ...     ...           ...
# 535271           1.25       17097   Spain          2.50
# 535272           4.95       17097   Spain          4.95
# 535273           1.95       17097   Spain          3.90
# 535274           2.08       17097   Spain          2.08
# 535275           2.89       17097   Spain          2.89
#
# [2485 rows x 13 columns]

# %%
orders.Country.value_counts()
# Out:
# United Kingdom          354345
# Germany                   9042
# France                    8342
# EIRE                      7238
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1842
# Portugal                  1462
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     248
# Unspecified                244
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              25
# Bahrain                     17
# Saudi Arabia                 9
# Name: Country, dtype: int64

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
orders.Country.value_counts()[['Spain']]
# Out:
# Spain    2485
# Name: Country, dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
orders[orders.Quantity > 50]
# Out:
#             InvoiceNo StockCode  year  month  day  hour  \
# Unnamed: 0
# 46             536371     22086  2010     12    3     9
# 83             536376     21733  2010     12    3     9
# 96             536378     21212  2010     12    3     9
# 102            536378    85071B  2010     12    3     9
# 176            536386    85099C  2010     12    3     9
# ...               ...       ...   ...    ...  ...   ...
# 541702         581566     23404  2011     12    5    11
# 541703         581567     21417  2011     12    5    11
# 541711         581567     21326  2011     12    5    11
# 541746         581571     23167  2011     12    5    12
# 541867         581584     20832  2011     12    5    12
#
#                                    Description  Quantity          InvoiceDate  \
# Unnamed: 0
# 46             paper chain kit 50's christmas         80  2010-12-01 09:00:00
# 83            red hanging heart t-light holder        64  2010-12-01 09:32:00
# 96             pack of 72 retrospot cake cases       120  2010-12-01 09:37:00
# 102         red charlie+lola personal doorsign        96  2010-12-01 09:37:00
# 176             jumbo  bag baroque black white       100  2010-12-01 09:57:00
# ...                                        ...       ...                  ...
# 541702              home sweet home blackboard       144  2011-12-09 11:50:00
# 541703                       cockle shell dish        84  2011-12-09 11:56:00
# 541711        aged glass silver t-light holder       144  2011-12-09 11:56:00
# 541746          small ceramic top storage jar         96  2011-12-09 12:00:00
# 541867        red flock love heart photo frame        72  2011-12-09 12:25:00
#
#             UnitPrice  CustomerID         Country  amount_spent
# Unnamed: 0
# 46               2.55       13748  United Kingdom        204.00
# 83               2.55       15291  United Kingdom        163.20
# 96               0.42       14688  United Kingdom         50.40
# 102              0.38       14688  United Kingdom         36.48
# 176              1.65       16029  United Kingdom        165.00
# ...               ...         ...             ...           ...
# 541702           3.26       18102  United Kingdom        469.44
# 541703           0.79       16626  United Kingdom         66.36
# 541711           0.55       16626  United Kingdom         79.20
# 541746           0.69       15311  United Kingdom         66.24
# 541867           0.72       13777  United Kingdom         51.84
#
# [11609 rows x 13 columns]

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
orders[(orders.Country == 'Spain')&(orders.Quantity > 50)]
# Out:
#             InvoiceNo StockCode  year  month  day  hour  \
# Unnamed: 0
# 6421           536944     22383  2010     12    5    12
# 6422           536944     22384  2010     12    5    12
# 6423           536944     20727  2010     12    5    12
# 6424           536944     20725  2010     12    5    12
# 6425           536944     20728  2010     12    5    12
# 52416          540785    84997B  2011      1    2    11
# 52417          540785    84997D  2011      1    2    11
# 52418          540785    84997C  2011      1    2    11
# 52419          540785    84997A  2011      1    2    11
# 136767         547972     22383  2011      3    1    16
# 136768         547972     22384  2011      3    1    16
# 136771         547972     20728  2011      3    1    16
# 248797         558871     22384  2011      7    1    13
# 248798         558871     20727  2011      7    1    13
# 248799         558871     20725  2011      7    1    13
# 248800         558871     20728  2011      7    1    13
# 248801         558871    84997B  2011      7    1    13
# 248802         558871    84997D  2011      7    1    13
# 248803         558871    84997C  2011      7    1    13
# 248804         558871    84997A  2011      7    1    13
# 282906         561669     23295  2011      7    4    17
# 282907         561669     23297  2011      7    4    17
# 282908         561669     23294  2011      7    4    17
# 282909         561669     23296  2011      7    4    17
# 282910         561669     23293  2011      7    4    17
# 315702         564734     84826  2011      8    7    13
# 355752         567968     85204  2011      9    5     9
# 398626         571255    82494L  2011     10    5    17
# 398631         571255     82482  2011     10    5    17
# 398639         571255    72802B  2011     10    5    17
# 398640         571255    72802C  2011     10    5    17
# 407272         571851     23167  2011     10    3    13
# 426665         573362     22598  2011     10    7    13
# 426666         573362     22597  2011     10    7    13
# 426667         573362     22599  2011     10    7    13
# 495739         578321     20728  2011     11    3    16
# 495740         578321    84997B  2011     11    3    16
# 495741         578321    84997D  2011     11    3    16
# 495742         578321    84997C  2011     11    3    16
#
#                                     Description  Quantity  \
# Unnamed: 0
# 6421                    lunch bag suki  design         70
# 6422                    lunch bag pink polkadot       100
# 6423                    lunch bag  black skull.        60
# 6424                    lunch bag red retrospot        70
# 6425                        lunch bag cars blue       100
# 52416         red 3 piece retrospot cutlery set       144
# 52417         pink 3 piece polkadot cutlery set       360
# 52418         blue 3 piece polkadot cutlery set       360
# 52419        green 3 piece polkadot cutlery set       144
# 136767                   lunch bag suki design        150
# 136768                  lunch bag pink polkadot       150
# 136771                      lunch bag cars blue       150
# 248797                  lunch bag pink polkadot       100
# 248798                  lunch bag  black skull.       100
# 248799                  lunch bag red retrospot       100
# 248800                      lunch bag cars blue       100
# 248801         childrens cutlery retrospot red         72
# 248802          childrens cutlery polkadot pink       360
# 248803          childrens cutlery polkadot blue       360
# 248804        childrens cutlery polkadot green         72
# 282906         set of 12 mini loaf baking cases       128
# 282907      set 40 heart shape petit four cases       144
# 282908         set of 6 snack loaf baking cases       128
# 282909           set of 6 tea time baking cases       128
# 282910        set of 12 fairy cake baking cases       128
# 315702           asstd design 3d paper stickers        60
# 355752             hanging wood and felt flower        96
# 398626              wooden frame antique white         72
# 398631        wooden picture frame white finish        72
# 398639       ocean scent candle in jewelled box       200
# 398640        vanilla scent candle jewelled box       288
# 407272           small ceramic top storage jar         96
# 426665              christmas musical zinc tree        72
# 426666           musical zinc heart decoration         72
# 426667              christmas musical zinc star        72
# 495739                      lunch bag cars blue       200
# 495740         childrens cutlery retrospot red         72
# 495741          childrens cutlery polkadot pink       360
# 495742          childrens cutlery polkadot blue       288
#
#                     InvoiceDate  UnitPrice  CustomerID Country  amount_spent
# Unnamed: 0
# 6421        2010-12-03 12:20:00       1.65       12557   Spain        115.50
# 6422        2010-12-03 12:20:00       1.45       12557   Spain        145.00
# 6423        2010-12-03 12:20:00       1.65       12557   Spain         99.00
# 6424        2010-12-03 12:20:00       1.65       12557   Spain        115.50
# 6425        2010-12-03 12:20:00       1.45       12557   Spain        145.00
# 52416       2011-01-11 11:39:00       3.39       12557   Spain        488.16
# 52417       2011-01-11 11:39:00       3.39       12557   Spain       1220.40
description  Quantity          InvoiceDate  \
# Unnamed: 0
# 93              lunch bag red retrospot        10  2010-12-01 09:37:00
# 174         lunch bag dolly girl design        10  2010-12-01 09:56:00
# 363         lunch bag dolly girl design         1  2010-12-01 11:21:00
# 368             lunch bag red retrospot         1  2010-12-01 11:21:00
# 369          lunch bag spaceboy design          2  2010-12-01 11:21:00
# ...                                 ...       ...                  ...
# 540436        lunch bag alphabet design        10  2011-12-09 09:38:00
# 541695          lunch bag  black skull.         1  2011-12-09 11:34:00
# 541696          lunch bag red retrospot         1  2011-12-09 11:34:00
# 541862      lunch bag red vintage doily        10  2011-12-09 12:20:00
# 541865          lunch bag red retrospot        40  2011-12-09 12:23:00
#
#             UnitPrice  CustomerID         Country  amount_spent
# Unnamed: 0
# 93               1.65       14688  United Kingdom         16.50
# 174              1.65       17420  United Kingdom         16.50
# 363              1.65       15862  United Kingdom          1.65
# 368              1.65       15862  United Kingdom          1.65
# 369              1.65       15862  United Kingdom          3.30
# ...               ...         ...             ...           ...
# 540436           1.65       17001  United Kingdom         16.50
# 541695           1.65       14446  United Kingdom          1.65
# 541696           1.65       14446  United Kingdom          1.65
# 541862           1.65       17581  United Kingdom         16.50
# 541865           1.45       13777  United Kingdom         58.00
#
# [11556 rows x 13 columns]

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
orders[(orders.Description.str.startswith('lunch bag'))&(orders.year == 2011)]
# Out:
#             InvoiceNo StockCode  year  month  day  hour  \
# Unnamed: 0
# 42678          540015     20725  2011      1    2    11
# 42679          540015     20726  2011      1    2    11
# 42851          540023     22382  2011      1    2    12
# 42852          540023     20726  2011      1    2    12
# 43616          540098     22384  2011      1    2    15
# ...               ...       ...   ...    ...  ...   ...
# 540436         581486     23207  2011     12    5     9
# 541695         581538     20727  2011     12    5    11
# 541696         581538     20725  2011     12    5    11
# 541862         581581     23681  2011     12    5    12
# 541865         581583     20725  2011     12    5    12
#
#                             Description  Quantity          InvoiceDate  \
# Unnamed: 0
# 42678           lunch bag red retrospot        10  2011-01-04 11:40:00
# 42679                lunch bag woodland        10  2011-01-04 11:40:00
# 42851        lunch bag spaceboy design          2  2011-01-04 12:58:00
# 42852                lunch bag woodland         1  2011-01-04 12:58:00
# 43616           lunch bag pink polkadot         1  2011-01-04 15:50:00
# ...                                 ...       ...                  ...
# 540436        lunch bag alphabet design        10  2011-12-09 09:38:00
# 541695          lunch bag  black skull.         1  2011-12-09 11:34:00
# 541696          lunch bag red retrospot         1  2011-12-09 11:34:00
# 541862      lunch bag red vintage doily        10  2011-12-09 12:20:00
# 541865          lunch bag red retrospot        40  2011-12-09 12:23:00
#
#             UnitPrice  CustomerID         Country  amount_spent
# Unnamed: 0
# 42678            1.65       13319  United Kingdom         16.50
# 42679            1.65       13319  United Kingdom         16.50
# 42851            1.65       15039  United Kingdom          3.30
# 42852            1.65       15039  United Kingdom          1.65
# 43616            1.65       16241  United Kingdom          1.65
# ...               ...         ...             ...           ...
# 540436           1.65       17001  United Kingdom         16.50
# 541695           1.65       14446  United Kingdom          1.65
# 541696           1.65       14446  United Kingdom          1.65
# 541862           1.65       17581  United Kingdom         16.50
# 541865           1.45       13777  United Kingdom         58.00
#
# [11234 rows x 13 columns]

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
orders.amount_spent[(orders.Country == 'Spain')].describe()
# Out:
# count    2485.000000
# mean       24.779521
# std        70.336782
# min         0.000000
# 25%         9.950000
# 50%        15.000000
# 75%        19.800000
# max      1350.000000
# Name: amount_spent, dtype: float64

# %%
orders.amount_spent[(orders.Country == 'Spain')].value_counts()
# Out:
# 15.00     186
# 17.70     122
# 19.80      99
# 17.40      86
# 10.20      76
#          ...
# 3.36        1
# 8.67        1
# 5.85        1
# 27.00       1
# 109.50      1
# Name: amount_spent, Length: 316, dtype: int64

# %%
orders.amount_spent[(orders.Country == 'Spain')].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397924 entries, 0 to 541908
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   InvoiceNo     397924 non-null  int64
#  1   StockCode     397924 non-null  object
#  2   year          397924 non-null  int64
#  3   month         397924 non-null  int64
#  4   day           397924 non-null  int64
#  5   hour          397924 non-null  int64
#  6   Description   397924 non-null  object
#  7   Quantity      397924 non-null  int64
#  8   InvoiceDate   397924 non-null  object
#  9   UnitPrice     397924 non-null  float64
#  10  CustomerID    397924 non-null  int64
#  11  Country       397924 non-null  object
#  12  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 50.6+ MB

# %%
orders[orders.month == 8]
# Out:
#             InvoiceNo StockCode  year  month  day  hour  \
# Unnamed: 0
# 285421         561904     22075  2011      8    1     8
# 285422         561904    85049E  2011      8    1     8
# 285423         561905     21385  2011      8    1     9
# 285424         561905    84970L  2011      8    1     9
# 285425         561905    84970S  2011      8    1     9
# ...               ...       ...   ...    ...  ...   ...
# 320688         565067     22644  2011      8    3    17
# 320689         565067     22645  2011      8    3    17
# 320690         565067     22637  2011      8    3    17
# 320691         565067     22646  2011      8    3    17
# 320692         565067     22741  2011      8    3    17
#
#                                     Description  Quantity  \
# Unnamed: 0
# 285421             6 ribbons elegant christmas         96
# 285422                scandinavian reds ribbons       156
# 285423          ivory hanging decoration  heart        24
# 285424         single heart zinc t-light holder        12
# 285425        hanging heart zinc t-light holder        12
# ...                                         ...       ...
# 320688           ceramic cherry cake money bank         2
# 320689      ceramic heart fairy cake money bank         2
# 320690                    piggy bank retrospot          2
# 320691       ceramic strawberry cake money bank         2
# 320692                           funky diva pen        48
#
#                     InvoiceDate  UnitPrice  CustomerID         Country  \
# Unnamed: 0
# 285421      2011-08-01 08:30:00       1.45       17941  United Kingdom
# 285422      2011-08-01 08:30:00       1.06       17941  United Kingdom
# 285423      2011-08-01 09:31:00       0.85       14947  United Kingdom
# 285424      2011-08-01 09:31:00       0.95       14947  United Kingdom
# 285425      2011-08-01 09:31:00       0.85       14947  United Kingdom
# ...                         ...        ...         ...             ...
# 320688      2011-08-31 17:16:00       1.45       15856  United Kingdom
# 320689      2011-08-31 17:16:00       1.45       15856  United Kingdom
# 320690      2011-08-31 17:16:00       2.55       15856  United Kingdom
# 320691      2011-08-31 17:16:00       1.45       15856  United Kingdom
# 320692      2011-08-31 17:16:00       0.85       15856  United Kingdom
#
#             amount_spent
# Unnamed: 0
# 285421            139.20
# 285422            165.36
# 285423             20.40
# 285424             11.40
# 285425             10.20
# ...                  ...
# 320688              2.90
# 320689              2.90
# 320690              5.10
# 320691              2.90
# 320692             40.80
#
# [27013 rows x 13 columns]

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
orders[orders.month == 8].groupby('Country').count()
# Out:
#                  InvoiceNo  StockCode   year  month    day   hour  \
# Country
# Australia              107        107    107    107    107    107
# Austria                 88         88     88     88     88     88
# Belgium                194        194    194    194    194    194
# Canada                   5          5      5      5      5      5
# Channel Islands        140        140    140    140    140    140
# Denmark                 16         16     16     16     16     16
# EIRE                   593        593    593    593    593    593
# Finland                 61         61     61     61     61     61
# France                 569        569    569    569    569    569
# Germany                795        795    795    795    795    795
# Iceland                 22         22     22     22     22     22
# Israel                 171        171    171    171    171    171
# Italy                   95         95     95     95     95     95
# Malta                   55         55     55     55     55     55
# Netherlands            280        280    280    280    280    280
# Norway                  77         77     77     77     77     77
# Poland                  17         17     17     17     17     17
# Portugal                41         41     41     41     41     41
# Spain                  252        252    252    252    252    252
# Sweden                  40         40     40     40     40     40
# Switzerland            267        267    267    267    267    267
# United Kingdom       23105      23105  23105  23105  23105  23105
# Unspecified             23         23     23     23     23     23
#
#                  Description  Quantity  InvoiceDate  UnitPrice  CustomerID  \
# Country
# Australia                107       107          107        107         107
# Austria                   88        88           88         88          88
# Belgium                  194       194          194        194         194
# Canada                     5         5            5          5           5
# Channel Islands          140       140          140        140         140
# Denmark                   16        16           16         16          16
# EIRE                     593       593          593        593         593
# Finland                   61        61           61         61          61
# France                   569       569          569        569         569
# Germany                  795       795          795        795         795
# Iceland                   22        22           22         22          22
# Israel                   171       171          171        171         171
# Italy                     95        95           95         95          95
# Malta                     55        55           55         55          55
# Netherlands              280       280          280        280         280
# Norway                    77        77           77         77          77
# Poland                    17        17           17         17          17
# Portugal                  41        41           41         41          41
# Spain                    252       252          252        252         252
# Sweden                    40        40           40         40          40
# Switzerland              267       267          267        267         267
# United Kingdom         23105     23105        23105      23105       23105
# Unspecified               23        23           23         23          23
#
#                  amount_spent
# Country
# Australia                 107
# Austria                    88
# Belgium                   194
# Canada                      5
# Channel Islands           140
# Denmark                    16
# EIRE                      593
# Finland                    61
# France                    569
# Germany                   795
# Iceland                    22
# Israel                    171
# Italy                      95
# Malta                      55
# Netherlands               280
# Norway                     77
# Poland                     17
# Portugal                   41
# Spain                     252
# Sweden                     40
# Switzerland               267
# United Kingdom          23105
# Unspecified                23

# %%
orders[orders.month == 8].groupby('Country').Country.count()
# Out:
# Country
# Australia            107
# Austria               88
# Belgium              194
# Canada                 5
# Channel Islands      140
# Denmark               16
# EIRE                 593
# Finland               61
# France               569
# Germany              795
# Iceland               22
# Israel               171
# Italy                 95
# Malta                 55
# Netherlands          280
# Norway                77
# Poland                17
# Portugal              41
# Spain                252
# Sweden                40
# Switzerland          267
# United Kingdom     23105
# Unspecified           23
# Name: Country, dtype: int64

# %%
orders.groupby('Country').count()
# Out:
#                       InvoiceNo  StockCode    year   month     day    hour  \
# Country
# Australia                  1185       1185    1185    1185    1185    1185
# Austria                     398        398     398     398     398     398
# Bahrain                      17         17      17      17      17      17
# Belgium                    2031       2031    2031    2031    2031    2031
# Brazil                       32         32      32      32      32      32
# Canada                      151        151     151     151     151     151
# Channel Islands             748        748     748     748     748     748
# Cyprus                      614        614     614     614     614     614
# Czech Republic               25         25      25      25      25      25
# Denmark                     380        380     380     380     380     380
# EIRE                       7238       7238    7238    7238    7238    7238
# European Community           60         60      60      60      60      60
# Finland                     685        685     685     685     685     685
# France                     8342       8342    8342    8342    8342    8342
# Germany                    9042       9042    9042    9042    9042    9042
# Greece                      145        145     145     145     145     145
# Iceland                     182        182     182     182     182     182
# Israel                      248        248     248     248     248     248
# Italy                       758        758     758     758     758     758
# Japan                       321        321     321     321     321     321
# Lebanon                      45         45      45      45      45      45
# Lithuania                    35         35      35      35      35      35
# Malta                       112        112     112     112     112     112
# Netherlands                2363       2363    2363    2363    2363    2363
# Norway                     1072       1072    1072    1072    1072    1072
# Poland                      330        330     330     330     330     330
# Portugal                   1462       1462    1462    1462    1462    1462
# RSA                          58         58      58      58      58      58
# Saudi Arabia                  9          9       9       9       9       9
# Singapore                   222        222     222     222     222     222
# Spain                      2485       2485    2485    2485    2485    2485
# Sweden                      451        451     451     451     451     451
# Switzerland                1842       1842    1842    1842    1842    1842
# USA                         179        179     179     179     179     179
# United Arab Emirates         68         68      68      68      68      68
# United Kingdom           354345     354345  354345  354345  354345  354345
# Unspecified                 244        244     244     244     244     244
#
#                       Description  Quantity  InvoiceDate  UnitPrice  \
# Country
# Australia                    1185      1185         1185       1185
# Austria                       398       398          398        398
# Bahrain                        17        17           17         17
# Belgium                      2031      2031         2031       2031
# Brazil                         32        32           32         32
# Canada                        151       151          151        151
# Channel Islands               748       748          748        748
# Cyprus                        614       614          614        614
# Czech Republic                 25        25           25         25
# Denmark                       380       380          380        380
# EIRE                         7238      7238         7238       7238
# European Community             60        60           60         60
# Finland                       685       685          685        685
# France                       8342      8342         8342       8342
# Germany                      9042      9042         9042       9042
# Greece                        145       145          145        145
# Iceland                       182       182          182        182
# Israel                        248       248          248        248
# Italy                         758       758          758        758
# Japan                         321       321          321        321
# Lebanon                        45        45           45         45
# Lithuania                      35        35           35         35
# Malta                         112       112          112        112
# Netherlands                  2363      2363         2363       2363
# Norway                       1072      1072         1072       1072
# Poland                        330       330          330        330
# Portugal                     1462      1462         1462       1462
# RSA                            58        58           58         58
# Saudi Arabia                    9         9            9          9
# Singapore                     222       222          222        222
# Spain                        2485      2485         2485       2485
# Sweden                        451       451          451        451
# Switzerland                  1842      1842         1842       1842
# USA                           179       179          179        179
# United Arab Emirates           68        68           68         68
# United Kingdom             354345    354345       354345     354345
# Unspecified                   244       244          244        244
#
#                       CustomerID  amount_spent
# Country
# Australia                   1185          1185
# Austria                      398           398
# Bahrain                       17            17
# Belgium                     2031          2031
# Brazil                        32            32
# Canada                       151           151
# Channel Islands              748           748
# Cyprus                       614           614
# Czech Republic                25            25
# Denmark                      380           380
# EIRE                        7238          7238
# European Community            60            60
# Finland                      685           685
# France                      8342          8342
# Germany                     9042          9042
# Greece                       145           145
# Iceland                      182           182
# Israel                       248           248
# Italy                        758           758
# Japan                        321           321
# Lebanon                       45            45
# Lithuania                     35            35
# Malta                        112           112
# Netherlands                 2363          2363
# Norway                      1072          1072
# Poland                       330           330
# Portugal                    1462          1462
# RSA                           58            58
# Saudi Arabia                   9             9
# Singapore                    222           222
# Spain                       2485          2485
# Sweden                       451           451
# Switzerland                 1842          1842
# USA                          179           179
# United Arab Emirates          68            68
# United Kingdom            354345        354345
# Unspecified                  244           244

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
orders.groupby('Country').amount_spent.mean()
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# Portugal                 22.872702
# RSA                      17.281207
# Saudi Arabia             16.213333
# Singapore                95.852658
# Spain                    24.779521
# Sweden                   85.096075
# Switzerland              30.642752
# USA                      20.002179
# United Arab Emirates     27.974706
# United Kingdom           20.625073
# Unspecified              10.930615
# Name: amount_spent, dtype: float64

# %%
orders.groupby('Country').amount_spent.agg('mean')
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# Portugal                 22.872702
# RSA                      17.281207
# Saudi Arabia             16.213333
# Singapore                95.852658
# Spain                    24.779521
# Sweden                   85.096075
# Switzerland              30.642752
# USA                      20.002179
# United Arab Emirates     27.974706
# United Kingdom           20.625073
# Unspecified              10.930615
# Name: amount_spent, dtype: float64

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
print('el articulo mas caro es:',orders.UnitPrice.max())
print('la venta mas cara es:',orders.amount_spent.max())
# Out:
# el articulo mas caro es: 8142.75
# la venta mas cara es: 168469.6

# %%
orders[orders.UnitPrice == orders.UnitPrice.max()]
# Out:
#             InvoiceNo StockCode  year  month  day  hour Description  Quantity  \
# Unnamed: 0
# 173382         551697      POST  2011      5    2    13     postage         1
#
#                     InvoiceDate  UnitPrice  CustomerID         Country  \
# Unnamed: 0
# 173382      2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#             amount_spent
# Unnamed: 0
# 173382           8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
orders.groupby('year').amount_spent.agg('mean')
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
