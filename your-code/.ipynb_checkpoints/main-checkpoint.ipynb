# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib as plt
import statistics

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
temp.dtypes
temp.info()
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      object
#  1   State        7 non-null      object
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
temp[temp['State'] == 'New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
np.mean(temp[temp['State'] == 'New York']['Temperature'])
# Out:
# 10.74074074074074

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp[temp['Temperature'] > 15.0][['City', 'State']]
# Out:
#        City        State
# 0       NYC     New York
# 3  Hartford  Connecticut
# 5    Treton   New Jersey
# 6    Newark   New Jersey

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp[temp['Temperature'] > 15.0][['City']]
# Out:
#        City
# 0       NYC
# 3  Hartford
# 5    Treton
# 6    Newark

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp[(temp['Temperature'] > 15.0) & (temp['Temperature'] < 20.0)][['City']]
# Out:
#        City
# 0       NYC
# 3  Hartford

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
temp.groupby('State').agg({'Temperature':['mean','std']}).reset_index()
# Out:
#          State Temperature
#                       mean       std
# 0  Connecticut   15.833333  1.964186
# 1   New Jersey   21.111111  1.571348
# 2     New York   10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee = pd.read_csv('Employee.csv')
employee.head()
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
employee.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001542880A748>,
# ...
#       dtype=object)

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
np.mean(employee['Salary'])
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
max(employee['Salary'])
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
min(employee['Salary'])
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
employee[employee['Salary'] == min(employee['Salary'])]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[employee['Name'] == 'David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee[employee['Name'] == 'David']['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee[employee['Title'] == 'associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[(employee['Title'] == 'associate') & (employee['Salary'] > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
employee.groupby('Years').agg({'Salary':'mean'}).reset_index()
# Out:
#    Years     Salary
# 0      1  35.000000
# 1      2  38.333333
# 2      3  55.000000
# 3      4  35.000000
# 4      7  60.000000
# 5      8  70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
employee.groupby('Title').agg({'Salary':'mean'}).reset_index()
# Out:
#        Title     Salary
# 0         VP  70.000000
# 1    analyst  32.500000
# 2  associate  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
employee.plot(kind='box')

# %%
# print first quartile here
employee.quantile(.25)
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
# print third quartile here
employee.quantile(.75)
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
employee.groupby('Gender').agg({'Salary':'mean'}).reset_index()
# Out:
#   Gender  Salary
# 0      F    47.5
# 1      M    50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
employee.groupby('Department').agg({'Years':['min', 'mean', 'max'], 'Salary':['min', 'mean', 'max']}).reset_index()
# Out:
#   Department Years               Salary
#                min      mean max    min   mean max
# 0         HR     2  4.666667   8     30  45.00  70
# 1         IT     1  4.500000   8     30  48.75  70
# 2      Sales     2  2.500000   3     55  55.00  55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here
employee.groupby('Department').agg({'Salary':np.ptp}).reset_index()
# Out:
#   Department  Salary
# 0         HR      40
# 1         IT      40
# 2      Sales       0

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv('Orders.csv')
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
# your answer here
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
np.mean(orders.groupby('InvoiceNo').agg({'amount_spent':'sum'}))
# Out:
# amount_spent    480.762187
# dtype: float64

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders.groupby('InvoiceNo').agg({'amount_spent':'sum'}).sort_values(by='amount_spent', ascending=False).reset_index()[0:1]
# Out:
#    InvoiceNo  amount_spent
# 0     581483      168469.6

# %%
# your answer here
orders.groupby('InvoiceNo').agg({'amount_spent':'sum'}).sort_values(by='amount_spent', ascending=False).reset_index()[-1:]
# Out:
#        InvoiceNo  amount_spent
# 18535     564651           0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
orders[orders['Country'] == 'Spain']['CustomerID'].unique().tolist()
# Out:
# [12557,
#  17097,
#  12540,
#  12551,
#  12484,
#  12539,
#  12510,
#  12421,
#  12502,
#  12462,
#  12507,
#  12541,
#  12547,
#  12597,
#  12545,
#  12596,
#  12354,
#  12417,
#  12455,
#  12450,
#  12548,
#  12556,
#  12550,
#  12546,
#  12454,
#  12448,
#  12544,
#  12538,
#  12445,
#  12442]

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
orders[orders['Country'] == 'Spain']['CustomerID'].value_counts()
# Out:
# 12540    478
# 12484    346
# 12539    273
# 17097    211
# 12597    206
# 12502    147
# 12556    121
# 12546     69
# 12462     62
# 12354     58
# 12550     57
# 12541     52
# 12545     50
# 12455     48
# 12421     45
# 12510     33
# 12557     33
# 12596     27
# 12417     23
# 12507     22
# 12448     22
# 12538     21
# 12544     19
# 12454     15
# 12442     12
# 12551     10
# 12547      8
# 12450      8
# 12548      5
# 12445      4
# Name: CustomerID, dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
df_customer_purchases = orders.groupby('CustomerID').agg({'Quantity':'sum'}).reset_index()
df_customer_purchases[df_customer_purchases['Quantity'] > 50].reset_index(drop=True)
#[orders.groupby('CustomerID').agg({'Quantity':'sum'})['Quantity'] > 50].reset_index()['CustomerID'].unique().tolist()
# Out:
#       CustomerID  Quantity
# 0          12346     74215
# 1          12347      2458
# 2          12348      2341
# 3          12349       631
# 4          12350       197
# ...          ...       ...
# 4086       18278        66
# 4087       18281        54
# 4088       18282       103
# 4089       18283      1397
# 4090       18287      1586
#
# [4091 rows x 2 columns]

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
df_customer_from_spain = orders.groupby(['InvoiceNo','Country']).agg({'Quantity':'sum'}).reset_index()
df_customer_from_spain[(df_customer_from_spain['Country'] == 'Spain') & (df_customer_from_spain['Quantity'] > 50)].reset_index(drop=True)
# Out:
#     InvoiceNo Country  Quantity
# 0      536944   Spain       400
# 1      538095   Spain        67
# 2      538525   Spain       300
# 3      539351   Spain       100
# 4      540469   Spain       630
# ..        ...     ...       ...
# 75     578321   Spain       920
# 76     578339   Spain        77
# 77     579503   Spain       117
# 78     580955   Spain       182
# 79     581193   Spain        92
#
# [80 rows x 3 columns]

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
df_free_orders = orders.groupby(['InvoiceNo']).agg({'amount_spent':'sum'}).reset_index()
df_free_orders[df_free_orders['amount_spent'] == 0]
# Out:
#        InvoiceNo  amount_spent
# 2721      543599           0.0
# 11301     564651           0.0
# 12848     568384           0.0
# 17360     578841           0.0

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
orders[orders['Description'].str.contains('lunch bag')]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
orders[(orders['Description'].str.contains('lunch bag')) & (pd.to_datetime(orders['InvoiceDate']).dt.year == 2011)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
df_orders_fd = orders[orders['Country'] == 'Spain'].groupby(['InvoiceNo']).agg({'amount_spent':'sum'})['amount_spent']
df_orders_fd.plot(kind='bar')

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders[pd.to_datetime(orders['InvoiceDate']).dt.month == 8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
orders[pd.to_datetime(orders['InvoiceDate']).dt.month == 8].groupby('Country')['InvoiceNo'].count().to_frame().reset_index()
# Out:
#             Country  InvoiceNo
# 0         Australia        107
# 1           Austria         88
# 2           Belgium        194
# 3            Canada          5
# 4   Channel Islands        140
# 5           Denmark         16
# 6              EIRE        593
# 7           Finland         61
# 8            France        569
# 9           Germany        795
# 10          Iceland         22
# 11           Israel        171
# 12            Italy         95
# 13            Malta         55
# 14      Netherlands        280
# 15           Norway         77
# 16           Poland         17
# 17         Portugal         41
# 18            Spain        252
# 19           Sweden         40
# 20      Switzerland        267
# 21   United Kingdom      23105
# 22      Unspecified         23

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
orders.groupby('Country').agg({'amount_spent':'mean'}).reset_index()
# Out:
#                  Country  amount_spent
# 0              Australia    116.895620
# 1                Austria     25.624824
# 2                Bahrain     32.258824
# 3                Belgium     20.283772
# 4                 Brazil     35.737500
# 5                 Canada     24.280662
# 6        Channel Islands     27.340160
# 7                 Cyprus     22.134169
# 8         Czech Republic     33.069600
# 9                Denmark     49.882474
# 10                  EIRE     36.687745
# 11    European Community     21.670833
# 12               Finland     32.913985
# 13                France     25.056827
# 14               Germany     25.311562
# 15                Greece     32.831172
# 16               Iceland     23.681319
# 17                Israel     29.119718
# 18                 Italy     23.064960
# 19                 Japan    116.561900
# 20               Lebanon     37.641778
# 21             Lithuania     47.458857
# 22                 Malta     24.335625
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
orders[orders['UnitPrice'] == max(orders['UnitPrice'])]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 118352      173382     551697      POST  2011      5    2    13     postage
#
#         Quantity          InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352         1  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
orders.groupby(pd.to_datetime(orders['InvoiceDate']).dt.year).agg({'amount_spent':'mean'}).reset_index()
# Out:
#    InvoiceDate  amount_spent
# 0         2010     21.892733
# 1         2011     22.430074
