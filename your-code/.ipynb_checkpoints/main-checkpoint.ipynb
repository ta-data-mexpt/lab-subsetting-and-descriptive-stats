# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv('C:/Users/jfcon/Dropbox/PC/Documents/Ironhack2022/modulo1/labs/lab-subsetting-and-descriptive-stats/your-code/Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      object
#  1   State        7 non-null      object
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 296.0+ bytes

# %%
temp.head(10)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
temp.dtypes

# city and state as object (object can be 'str', bool, )
# Temperature as float64 (as it includes decimals)
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
temp[temp['State'] =='New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
temp.Temperature.mean()
# Out:
# 15.15873015873016

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
temp[temp['Temperature'] > 15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp[['Temperature','City']][temp['Temperature'] > 15]
# Out:
#    Temperature      City
# 0    19.444444       NYC
# 3    17.222222  Hartford
# 5    22.222222    Treton
# 6    20.000000    Newark

# %%
temp.head(10)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp[['City','Temperature']][(temp['Temperature'] > 15) & (temp['Temperature'] < 20)]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
temp.groupby('State').agg({'Temperature':['mean','std']})
# Out:
#             Temperature
#                    mean       std
# State
# Connecticut   15.833333  1.964186
# New Jersey    21.111111  1.571348
# New York      10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
employee = pd.read_csv('C:/Users/jfcon/Dropbox/PC/Documents/Ironhack2022/modulo1/labs/lab-subsetting-and-descriptive-stats/your-code/Employee.csv')

# %%
employee.info
# Out:
# <bound method DataFrame.info of      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70>

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.dtypes
#Basically it can be found most of fields whose values are object type but Years and Salary that are int64
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
employee.hist()

''' It can be seen in charts below, that seniority top one is for the employees that have been working three years in the company 
    while two workers that have been working 8 years are located at the second place of the analysis results. 
    It can also be seen that people with highest seniority are the best paid in the company, above 60K, and the Lowest salaries are 
    for the employees with less seniority (i.e. 1 or 2 years).

'''
# Out:
# ' It can be seen in charts below, that seniority top one are located the employees that have been working three years in the company \n    while two workers that have been working 8 years are located at the second place of analysis results. \n    It can also be seen that people with highest seniority are the best paid in the company, above 60K, and the Lowest salaries are \n    for the employees with less seniority (i.e. 1 or 2 years)\n\n'

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
employee['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
#employee[employee.Salary == employee.Salary.min()][['Name','Salary']]

employee[employee['Salary'] == employee['Salary'].min()][['Name','Salary']]
# Out:
#     Name  Salary
# 1  Maria      30
# 2  David      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[employee.Name =='David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee[employee.Name=='David'][['Name', 'Salary']]
# Out:
#     Name  Salary
# 2  David      30

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee[employee.Title == 'associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[(employee.Title == 'associate') & (employee.Salary > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
employee.groupby('Years').Salary.mean()
# Out:
# Years
# 1    35.000000
# 2    38.333333
# 3    55.000000
# 4    35.000000
# 7    60.000000
# 8    70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
employee.groupby('Title').Salary.mean()
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
employee.boxplot()
# Out:
# <AxesSubplot:>

# %%
# print first quartile here
employee.quantile(.25)
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
# print third quartile here
employee.quantile(.75)
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
employee.groupby('Gender').Salary.mean()
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %%
employee.head(10)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
employee.groupby('Department').agg(['min','mean','max'])
# Out:
#            Years               Salary
#              min      mean max    min   mean max
# Department
# HR             2  4.666667   8     30  45.00  70
# IT             1  4.500000   8     30  48.75  70
# Sales          2  2.500000   3     55  55.00  55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here
df0 = employee.groupby('Department').agg(['max','min'])
sal_diff = df0['Salary']['max'] - df0['Salary']['min']
sal_diff.head()
# Out:
# Department
# HR       40
# IT       40
# Sales     0
# dtype: int64

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders= pd.read_csv('C:/Users/jfcon/Dropbox/PC/Documents/Ironhack2022/modulo1/labs/lab-subsetting-and-descriptive-stats/your-code/orders.csv')

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
orders.describe().T

''' it can be seen that values types are assorted among int64, float64 and object.  

'''
# Out:
#                  count           mean            std       min        25%  \
# Unnamed: 0    397924.0  278465.221859  152771.368303       0.0  148333.75
# InvoiceNo     397924.0  560617.126645   13106.167695  536365.0  549234.00
# year          397924.0    2010.934259       0.247829    2010.0    2011.00
# month         397924.0       7.612537       3.416527       1.0       5.00
# day           397924.0       3.614555       1.928274       1.0       2.00
# hour          397924.0      12.728247       2.273535       6.0      11.00
# Quantity      397924.0      13.021823     180.420210       1.0       2.00
# UnitPrice     397924.0       3.116174      22.096788       0.0       1.25
# CustomerID    397924.0   15294.315171    1713.169877   12346.0   13969.00
# amount_spent  397924.0      22.394749     309.055588       0.0       4.68
#
#                     50%        75%        max
# Unnamed: 0    284907.50  410079.25  541908.00
# InvoiceNo     561893.00  572090.00  581587.00
# ...

# %%
orders.dtypes.sort_values()
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# year              int64
# month             int64
# day               int64
# hour              int64
# Quantity          int64
# CustomerID        int64
# UnitPrice       float64
# amount_spent    float64
# StockCode        object
# Description      object
# InvoiceDate      object
# Country          object
# dtype: object

# %%
orders.head(10)
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
# 5           5     536365     22752  2010     12    3     8
# 6           6     536365     21730  2010     12    3     8
# 7           7     536366     22633  2010     12    3     8
# 8           8     536366     22632  2010     12    3     8
# 9           9     536367     84879  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
orders['amount_spent'].mean()
# Out:
# 22.39474850474768

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders['amount_spent'].max()
# Out:
# 168469.6

# %%
# your answer here
orders['amount_spent'].min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
df = orders.set_index('Country')
df
# Out:
#                 Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# Country
# United Kingdom           0     536365    85123A  2010     12    3     8
# United Kingdom           1     536365     71053  2010     12    3     8
# United Kingdom           2     536365    84406B  2010     12    3     8
# United Kingdom           3     536365    84029G  2010     12    3     8
# United Kingdom           4     536365    84029E  2010     12    3     8
# ...                    ...        ...       ...   ...    ...  ...   ...
# France              541904     581587     22613  2011     12    5    12
# France              541905     581587     22899  2011     12    5    12
# France              541906     581587     23254  2011     12    5    12
# France              541907     581587     23255  2011     12    5    12
# France              541908     581587     22138  2011     12    5    12
#
#                                         Description  Quantity  \
# Country
# ...

# %%
df[['amount_spent','month','year']]
# Out:
#                 amount_spent  month  year
# Country
# United Kingdom         15.30     12  2010
# United Kingdom         20.34     12  2010
# United Kingdom         22.00     12  2010
# United Kingdom         20.34     12  2010
# United Kingdom         20.34     12  2010
# ...                      ...    ...   ...
# France                 10.20     12  2011
# France                 12.60     12  2011
# France                 16.60     12  2011
# France                 16.60     12  2011
# France                 14.85     12  2011
#
# [397924 rows x 3 columns]

# %%
# your answer here
orders[orders['Country'] == 'Spain']
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# ...            ...        ...       ...   ...    ...  ...   ...
# 394733      535271     581193     23291  2011     12    3    17
# 394734      535272     581193    85232D  2011     12    3    17
# 394735      535273     581193     22721  2011     12    3    17
# 394736      535274     581193     23241  2011     12    3    17
# 394737      535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
orders['Country'].value_counts()['Spain']
# Out:
# 2485

# %%
orders.head(10)
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
# 5           5     536365     22752  2010     12    3     8
# 6           6     536365     21730  2010     12    3     8
# 7           7     536366     22633  2010     12    3     8
# 8           8     536366     22632  2010     12    3     8
# 9           9     536367     84879  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
orders[['CustomerID','Quantity']][orders['Quantity'] > 50]
# Out:
#         CustomerID  Quantity
# 46           13748        80
# 83           15291        64
# 96           14688       120
# 102          14688        96
# 174          16029       100
# ...            ...       ...
# 397720       18102       144
# 397721       16626        84
# 397729       16626       144
# 397761       15311        96
# 397882       13777        72
#
# [11609 rows x 2 columns]

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
orders[['CustomerID','Quantity']][(orders['Quantity'] > 50) & (orders['Country'] == 'Spain')]
# Out:
#         CustomerID  Quantity
# 4250         12557        70
# 4251         12557       100
# 4252         12557        60
# 4253         12557        70
# 4254         12557       100
# 32454        12557       144
# 32455        12557       360
# 32456        12557       360
# 32457        12557       144
# 91155        12557       150
# 91156        12557       150
# 91159        12557       150
# 174442       12557       100
# 174443       12557       100
# 174444       12557       100
# 174445       12557       100
# 174446       12557        72
# 174447       12557       360
# 174448       12557       360
# 174449       12557        72
# 197167       12507       128
# 197168       12507       144
# 197169       12507       128
# 197170       12507       128
# 197171       12507       128
# 224881       12484        60
# 254097       12546        96
# 289129       12454        72
# 289134       12454        72
# 289142       12454       200
# 289143       12454       288
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
orders[['CustomerID','amount_spent']][orders['UnitPrice'] == 0]
# Out:
#         CustomerID  amount_spent
# 6914         12647           0.0
# 22539        16560           0.0
# 25379        14911           0.0
# 29080        13081           0.0
# 29082        13081           0.0
# 34494        15107           0.0
# 53788        17560           0.0
# 85671        13239           0.0
# 92875        13113           0.0
# 97430        14410           0.0
# 107192       12457           0.0
# 128641       17667           0.0
# 137127       12415           0.0
# 194648       16818           0.0
# 197173       12507           0.0
# 199711       15581           0.0
# 208950       14911           0.0
# 223931       14646           0.0
# 223932       14646           0.0
# 223933       14646           0.0
# 223934       14646           0.0
# 256263       16133           0.0
# 259399       12748           0.0
# 273926       15804           0.0
# 286507       12446           0.0
# 307092       18059           0.0
# 319882       12415           0.0
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
orders[orders.Description.str.contains('lunch bag')]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
orders[(orders['Description'].str.contains('lunch bag')) & (orders['year']==2011)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here

orders.amount_spent[orders.Country == 'Spain'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders[orders.month == 8].value_counts()
# Out:
# Unnamed: 0  InvoiceNo  StockCode  year  month  day  hour  Description                          Quantity  InvoiceDate          UnitPrice  CustomerID  Country         amount_spent
# 285421      561904     22075      2011  8      1    8     6 ribbons elegant christmas          96        2011-08-01 08:30:00  1.45       17941       United Kingdom  139.20          1
# 307585      563924     84978      2011  8      7    14    hanging heart jar t-light holder     6         2011-08-21 14:32:00  1.25       15984       United Kingdom  7.50            1
# 307609      563924     21974      2011  8      7    14    set of 36 paisley flower doilies     1         2011-08-21 14:32:00  1.45       15984       United Kingdom  1.45            1
# 307608      563924     18097C     2011  8      7    14    white tall porcelain t-light holder  1         2011-08-21 14:32:00  2.55       15984       United Kingdom  2.55            1
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
orders.Country[orders.month == 8].value_counts()
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
orders.groupby('Country').amount_spent.mean()
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
orders['UnitPrice'].max()
# Out:
# 8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
orders.groupby('year').mean()
# Out:
#          Unnamed: 0      InvoiceNo      month       day       hour   Quantity  \
# year
# 2010   19884.040482  538009.305122  12.000000  3.745528  12.897630  11.937309
# 2011  296660.861310  562207.976246   7.303803  3.605338  12.716328  13.098138
#
#       UnitPrice    CustomerID  amount_spent
# year
# 2010   3.132095  15529.088417     21.892733
# 2011   3.115054  15277.794830     22.430074
